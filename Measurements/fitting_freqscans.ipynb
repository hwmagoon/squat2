# %%
from qick_data import *
from lorentz_fits import *
import numpy as np
import os
import sys

# %%
## Pull the data
datapath = 'c:\\Users\\Hannah\\Desktop\\SLAC\\squat2\\Data\\Selected_freqscans'
os.chdir(datapath)
flist = os.listdir()

## Read in and fit degenerate parity data
fn = flist[0]
f = read_H5(datapath=datapath, filename=fn, dataclass=QICKdata)
freqs = f.meas_data['RF_freqs']
xi = f.meas_data['Ivals']
xq = f.meas_data['Qvals']
fit_double_lorentz(freqs, xi, xq, plot=True, plot_title=f.meta['series'])
# Out:
# Reading from filepath c:\Users\Hannah\Desktop\SLAC\squat2\Data\Selected_freqscans
# Creating dataset with series 20240513_065046
# 13.704928233673886 14.121265205385216 negative
# {'g_f0': 7352.5,
#  'g_amp': -3.9417300531528823,
#  'g_gamma': 0.1,
#  'g_offset': 14.121265205385216,
#  'f_L_f0': 7356.522572879525,
#  'f_R_f0': 7347.23360091293,
#  'f_amp': -6.9950117564254874,
#  'f_gamma': 1.1617962940192283,
#  'f_offset': 14.244522561077677}

# %%
fn = flist[1]
f = read_H5(datapath=datapath, filename=fn, dataclass=QICKdata)
freqs = f.meas_data['RF_freqs']
xi = f.meas_data['Ivals']
xq = f.meas_data['Qvals']
fit_double_lorentz(freqs, xi, xq, plot=True, plot_title=f.meta['series'])
# Out:
# Reading from filepath c:\Users\Hannah\Desktop\SLAC\squat2\Data\Selected_freqscans
# Creating dataset with series 20240513_065304
# 1.8541309823148875 1.1513930339249732 positive
# [3.61156825 3.61341286 3.6325285  3.66625876 3.74686697 3.77389251
#  3.78022271 3.78355148]
# {'g_f0': 7352.5,
#  'g_amp': 3.701037755966275,
#  'g_gamma': 0.1,
#  'g_offset': 1.1513930339249732,
#  'f_L_f0': 7356.389353585693,
#  'f_R_f0': 7346.83554050377,
#  'f_amp': 10.763639397646026,
#  'f_gamma': 1.991605879849826,
#  'f_offset': 1.0455236025620804}

# %%
fn = flist[2]
f = read_H5(datapath=datapath, filename=fn, dataclass=QICKdata)
freqs = f.meas_data['RF_freqs']
xi = f.meas_data['Ivals']
xq = f.meas_data['Qvals']
fit_lorentz(freqs, xi, xq, plot=True, plot_title=f.meta['series'])
# Out:
# Reading from filepath c:\Users\Hannah\Desktop\SLAC\squat2\Data\Selected_freqscans
# Creating dataset with series 20240513_074657
# 2.0646825555212027 1.1771323723235714 positive
# [7.31932943 7.49081233 7.52801341 7.54273786 7.5854781  7.61586359
#  7.6315682  7.93430681]
# {'g_f0': 7352.5,
#  'g_amp': 7.581013716741146,
#  'g_gamma': 0.1,
#  'g_offset': 1.1771323723235714,
#  'f_f0': 7351.475930534725,
#  'f_amp': 25.232588859252914,
#  'f_gamma': 2.2024314540930536,
#  'f_offset': 1.1134949454260108,
#  'f_err': array([0.01010232, 0.30897879, 0.0331468 , 0.0165946 ])}

# %%
fn = flist[3]
f = read_H5(datapath=datapath, filename=fn, dataclass=QICKdata)
freqs = f.meas_data['RF_freqs']
xi = f.meas_data['Ivals']
xq = f.meas_data['Qvals']
fit_lorentz(freqs, xi, xq, plot=True, plot_title=f.meta['series'])
# Out:
# Reading from filepath c:\Users\Hannah\Desktop\SLAC\squat2\Data\Selected_freqscans
# Creating dataset with series 20240513_074848
# 13.750105454610758 14.086930077167349 negative
# {'g_f0': 7352.5,
#  'g_amp': -8.190896545182646,
#  'g_gamma': 0.1,
#  'g_offset': 14.086930077167349,
#  'f_f0': 7351.685748767877,
#  'f_amp': -12.610038220642792,
#  'f_gamma': 0.9259205224628473,
#  'f_offset': 14.24188255746565,
#  'f_err': array([0.00469083, 0.14385445, 0.01408758, 0.01191947])}
